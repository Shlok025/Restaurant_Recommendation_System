# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
resturant_df = pd.read_csv('dataset/restaurants.csv')
resturant_df
# Out:
#      Restaurant_ID                        Name             City  \
# 0           132560          Puesto de Gorditas  Ciudad Victoria
# 1           132561                  Cafe Ambar  Ciudad Victoria
# 2           132564                    Church's  Ciudad Victoria
# 3           132572                Cafe Chaires  San Luis Potosi
# 4           132583            McDonalds Centro       Cuernavaca
# ..             ...                         ...              ...
# 125         135088           Cafeteria Cenidet       Cuernavaca
# 126         135104                        Vips  Ciudad Victoria
# 127         135106  El Rincón De San Francisco  San Luis Potosi
# 128         135108                  Potzocalli  San Luis Potosi
# 129         135109                   Paniroles       Cuernavaca
#
#                State Country  Zip_Code   Latitude   Longitude Alcohol_Service  \
# 0         Tamaulipas  Mexico       NaN  23.752304  -99.166913             NaN
# ...

# %%
resturant_df.shape
# Out:
# (130, 14)

# %%
resturant_df.describe()
# Out:
#        Restaurant_ID      Zip_Code    Latitude   Longitude
# count     130.000000     56.000000  130.000000  130.000000
# mean   134012.784615  75790.714286   21.858863 -100.342933
# std      1140.644582   6018.162410    1.496830    0.860585
# min    132560.000000  62000.000000   18.859803 -101.028600
# 25%    132831.000000  78000.000000   22.139574 -100.987838
# 50%    134994.000000  78212.000000   22.149063 -100.956777
# 75%    135050.750000  78310.000000   22.160125  -99.220458
# max    135109.000000  87018.000000   23.760268  -99.126506

# %%
resturant_df.isna().sum()
# Out:
# Restaurant_ID       0
# Name                0
# City                0
# State               0
# Country             0
# Zip_Code           74
# Latitude            0
# Longitude           0
# Alcohol_Service    87
# Smoking_Allowed     0
# Price               0
# Franchise           0
# Area                0
# Parking            65
# dtype: int64

# %%
resturant_df['Parking'] = resturant_df['Parking'].replace(np.nan, 'No')

# %%
resturant_df.isna().sum()
# Out:
# Restaurant_ID       0
# Name                0
# City                0
# State               0
# Country             0
# Zip_Code           74
# Latitude            0
# Longitude           0
# Alcohol_Service    87
# Smoking_Allowed     0
# Price               0
# Franchise           0
# Area                0
# Parking             0
# dtype: int64

# %%
resturant_df['Parking']
# Out:
# 0      Public
# 1          No
# 2          No
# 3         Yes
# 4          No
#         ...
# 125    Public
# 126       Yes
# 127        No
# 128        No
# 129        No
# Name: Parking, Length: 130, dtype: object

# %%
resturant_df['Alcohol_Service']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 125            NaN
# 126       Full Bar
# 127    Wine & Beer
# 128            NaN
# 129    Wine & Beer
# Name: Alcohol_Service, Length: 130, dtype: object

# %%
resturant_df['Alcohol_Service'].describe()
# Out:
# count              43
# unique              2
# top       Wine & Beer
# freq               34
# Name: Alcohol_Service, dtype: object

# %%
resturant_df['Alcohol_Service'].unique()
# Out:
# array([nan, 'Full Bar', 'Wine & Beer'], dtype=object)

# %%
resturant_df['Alcohol_Service'] = resturant_df['Alcohol_Service'].replace(np.nan, 'No Service')

# %%
resturant_df.isna().sum()
# Out:
# Restaurant_ID       0
# Name                0
# City                0
# State               0
# Country             0
# Zip_Code           74
# Latitude            0
# Longitude           0
# Alcohol_Service     0
# Smoking_Allowed     0
# Price               0
# Franchise           0
# Area                0
# Parking             0
# dtype: int64

# %%
resturant_df = resturant_df.drop('Zip_Code', axis=1)

# %%
resturant_df
# Out:
#      Restaurant_ID                        Name             City  \
# 0           132560          Puesto de Gorditas  Ciudad Victoria
# 1           132561                  Cafe Ambar  Ciudad Victoria
# 2           132564                    Church's  Ciudad Victoria
# 3           132572                Cafe Chaires  San Luis Potosi
# 4           132583            McDonalds Centro       Cuernavaca
# ..             ...                         ...              ...
# 125         135088           Cafeteria Cenidet       Cuernavaca
# 126         135104                        Vips  Ciudad Victoria
# 127         135106  El Rincón De San Francisco  San Luis Potosi
# 128         135108                  Potzocalli  San Luis Potosi
# 129         135109                   Paniroles       Cuernavaca
#
#                State Country   Latitude   Longitude Alcohol_Service  \
# 0         Tamaulipas  Mexico  23.752304  -99.166913      No Service
# ...

# %%
resturant_df.isna().sum()
# Out:
# Restaurant_ID      0
# Name               0
# City               0
# State              0
# Country            0
# Latitude           0
# Longitude          0
# Alcohol_Service    0
# Smoking_Allowed    0
# Price              0
# Franchise          0
# Area               0
# Parking            0
# dtype: int64

# %%
resturant_df.to_csv('cleaned_resturant.csv', index=False)
